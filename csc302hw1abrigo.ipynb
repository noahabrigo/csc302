# %% [markdown]
# <a href="https://colab.research.google.com/github/noahabrigo/csc302/blob/main/csc302hw1abrigo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 2:  Use pandas to read the olympic_medals.csv from the DATA folder on Google Drive. Then perform the followings by
# using pandas and/or Python built-in functions

# %% [markdown]
# a)Find the size of the data frame. How many rows, how many columns?

# %%
import pandas as pd
olym = pd.read_csv('/content/drive/MyDrive/DATA/olympic_medals.csv')
olym.shape
# Out:
#      Gender              Event  ... Nationality    Result
# 0         M         10000M Men  ...         GBR  25:05.17
# 1         M         10000M Men  ...         KEN  27:05.64
# 2         M         10000M Men  ...         ETH  27:06.26
# 3         M         10000M Men  ...         ETH  27:01.17
# 4         M         10000M Men  ...         ETH  27:02.77
# ...     ...                ...  ...         ...       ...
# 2389      W  Triple Jump Women  ...         GRE     15.25
# 2390      W  Triple Jump Women  ...         RUS     15.14
# 2391      W  Triple Jump Women  ...         UKR     15.33
# 2392      W  Triple Jump Women  ...         RUS     14.98
# 2393      W  Triple Jump Women  ...         CZE     14.98
#
# [2394 rows x 8 columns]

# %% [markdown]
# b) Use the appropriate function to report the data types for all columns

# %%
olym.dtypes
# Out:
# Gender         object
# Event          object
# Location       object
# Year            int64
# Medal          object
# Name           object
# Nationality    object
# Result         object
# dtype: object

# %% [markdown]
# c)Find how many unique locations olympics were held at.

# %%
olym.loc[:,['Location']].drop_duplicates()
# Out:
#                   Location
# 0                      Rio
# 3                  Beijing
# 6                   Sydney
# 9                Barcelona
# 12             Los Angeles
# 15                Montreal
# 18                  Mexico
# 21                    Rome
# 24                Helsinki
# 27                  Berlin
# 30               Amsterdam
# 33                 Antwerp
# 36                  London
# 39                  Athens
# 42                 Atlanta
# 45                  Moscow
# 48                  Munich
# 51                   Tokyo
# 54   Melbourne / Stockholm
# 63                   Paris
# 66               Stockholm
# 144               St Louis
# 423                  Seoul

# %% [markdown]
# d) Find how many medals the USA team won in total.

# %%
olym[olym['Nationality'] == "USA"].count()
# Out:
# Gender         638
# Event          638
# Location       638
# Year           638
# Medal          638
# Name           577
# Nationality    638
# Result         638
# dtype: int64

# %% [markdown]
# e) Find the total number of medals for each Nationality. (Hint: please search for groupby() function with sum)

# %%
olym.groupby(['Nationality']).count()
# Out:
#              Gender  Event  Location  Year  Medal  Name  Result
# Nationality
# ALG               9      9         9     9      9     9       9
# ARG               4      4         4     4      4     4       4
# AUS              57     57        57    57     57    53      57
# AUT               4      4         4     4      4     4       4
# BAH              12     12        12    12     12     6      12
# ...             ...    ...       ...   ...    ...   ...     ...
# URS             131    131       131   131    131   119     131
# USA             638    638       638   638    638   577     638
# VEN               2      2         2     2      2     2       2
# YUG               1      1         1     1      1     1       1
# ZAM               1      1         1     1      1     1       1
#
# [97 rows x 7 columns]

# %% [markdown]
# Part 3: Use pandas to read the causes_of_death.csv from the DATA folder on Google Drive. Then perform the followings
# by using pandas and/or Python built-in functions.

# %% [markdown]
# a) Find the size of the data frame. How many rows, how many columns?

# %%
import pandas as pd
death = pd.read_csv('/content/drive/MyDrive/DATA/causes_of_death.csv')
death.shape
# Out:
# (4115, 11)

# %% [markdown]
# b) What is the average death count across the country?

# %%
death['Deaths'].mean()
# Out:
# 10914.44957472661

# %% [markdown]
# c) What is the total death count for each state. (Hint: please search for groupby() function with sum)

# %%
death.groupby(by=['State']).count()
# Out:
#                       State Code  Ten-Year Age Groups  ...  Population  Crude Rate
# State                                                  ...
# Alabama                       81                   81  ...          80          76
# Alaska                        82                   82  ...          82          79
# Arizona                       92                   92  ...          88          88
# Arkansas                      81                   81  ...          81          75
# California                    94                   94  ...          88          88
# Colorado                      88                   88  ...          87          84
# Connecticut                   81                   81  ...          79          73
# Delaware                      69                   69  ...          69          62
# District of Columbia          65                   65  ...          62          53
# Florida                       90                   90  ...          86          83
# Georgia                       86                   86  ...          84          83
# Hawaii                        76                   76  ...          76          71
# Idaho                         72                   72  ...          72          66
# Illinois                      87                   87  ...          83          80
# Indiana                       80                   80  ...          79          72
# Iowa                          82                   82  ...          82          76
# Kansas                        83                   83  ...          83          79
# Kentucky                      76                   76  ...          75          69
# Louisiana                     83                   83  ...          82          77
# Maine                         70                   70  ...          70          59
# Maryland                      87                   87  ...          83          79
# Massachusetts                 81                   81  ...          80          78
# Michigan                      89                   89  ...          88          84
# Minnesota                     88                   88  ...          88          88
# Mississippi                   86                   86  ...          82          78
# Missouri                      85                   85  ...          83          76
# Montana                       72                   72  ...          72          60
# Nebraska                      80                   80  ...          80          76
# Nevada                        86                   86  ...          84          83
# New Hampshire                 62                   62  ...          62          48
# New Jersey                    84                   84  ...          80          77
# New Mexico                    87                   87  ...          84          77
# New York                      92                   92  ...          88          84
# North Carolina                91                   91  ...          88          87
# North Dakota                  65                   65  ...          65          53
# Ohio                          81                   81  ...          81          78
# Oklahoma                      89                   89  ...          88          84
# Oregon                        88                   88  ...          88          78
# Pennsylvania                  85                   85  ...          81          80
# Rhode Island                  72                   72  ...          71          66
# South Carolina                81                   81  ...          78          75
# South Dakota                  69                   69  ...          69          58
# Tennessee                     81                   81  ...          80          75
# Texas                         90                   90  ...          87          84
# Utah                          86                   86  ...          85          76
# Vermont                       49                   49  ...          49          33
# Virginia                      85                   85  ...          83          81
# Washington                    89                   89  ...          88          88
# West Virginia                 62                   62  ...          62          52
# Wisconsin                     88                   88  ...          88          82
# Wyoming                       67                   67  ...          67          54
#
# [51 rows x 10 columns]

# %% [markdown]
# d) What is the average death count for each state. (Hint: please search for groupby() function with mean)

# %%
death.groupby('State').mean()
# Out:
#                       State Code        Deaths    Population   Crude Rate
# State
# Alabama                      1.0  10626.913580  1.046829e+06  2051.435526
# Alaska                       2.0    772.365854  1.480601e+05  2256.459494
# Arizona                      4.0   9109.717391  1.240811e+06  1861.282955
# Arkansas                     5.0   6455.728395  6.288683e+05  2195.386667
# California                   6.0  45819.797872  7.474228e+06  1680.935227
# e) What is the total death count for males and females in each state. (Hint: groupby() function with sum, but you
# will have two attributes/columns for the groupby() )

# %%
death.groupby(by=['Gender','Gender Code']).sum()
# Out:
#                     State Code    Deaths    Population  Crude Rate
# Gender Gender Code
# Female F                 57593  22568333  2.758048e+09   3485519.3
# Male   M                 60317  22344627  2.668546e+09   4326767.7

# %% [markdown]
# f) Drop your rows which have NA in it. Then verify it by using head() to show they are removed. (Hint: dropna())

# %%
death.dropna().head()
# Out:
#      State  State Code Ten-Year Age Groups  ... Population Crude Rate     ratio
# 1  Alabama           1            < 1 year  ...     7443.0      322.5  0.003225
# 2  Alabama           1            < 1 year  ...   169339.0     1236.0  0.012360
# 3  Alabama           1            < 1 year  ...   347921.0      616.2  0.006162
# 4  Alabama           1            < 1 year  ...     7366.0      448.0  0.004480
# 5  Alabama           1            < 1 year  ...   173241.0     1577.0  0.015770
#
# [5 rows x 12 columns]

# %% [markdown]
# g) Create a column called ratio and assign the ratio of death counts to population to fill its values. Then verify it
# by using head().

# %%
death['ratio'] = death['Deaths']/death['Population']
death.head()
# Out:
#      State  State Code Ten-Year Age Groups  ... Population Crude Rate     ratio
# 0  Alabama           1            < 1 year  ...     3579.0        NaN  0.003912
# 1  Alabama           1            < 1 year  ...     7443.0      322.5  0.003225
# 2  Alabama           1            < 1 year  ...   169339.0     1236.0  0.012360
# 3  Alabama           1            < 1 year  ...   347921.0      616.2  0.006162
# 4  Alabama           1            < 1 year  ...     7366.0      448.0  0.004480
#
# [5 rows x 12 columns]

# %% [markdown]
# h) Select only rows where Ten-Year Age Groups Code is equal to 1. Notice that this column has string data type.

# %%
death[death['Ten-Year Age Groups Code'] == '1']
# Out:
#         State  State Code Ten-Year Age Groups  ... Population Crude Rate     ratio
# 0     Alabama           1            < 1 year  ...     3579.0        NaN  0.003912
# 1     Alabama           1            < 1 year  ...     7443.0      322.5  0.003225
# 2     Alabama           1            < 1 year  ...   169339.0     1236.0  0.012360
# 3     Alabama           1            < 1 year  ...   347921.0      616.2  0.006162
# 4     Alabama           1            < 1 year  ...     7366.0      448.0  0.004480
# ...       ...         ...                 ...  ...        ...        ...       ...
# 4048  Wyoming          56            < 1 year  ...     3260.0        NaN  0.005828
# 4049  Wyoming          56            < 1 year  ...    57791.0      565.8  0.005658
# 4050  Wyoming          56            < 1 year  ...     3366.0     1218.1  0.012181
# 4051  Wyoming          56            < 1 year  ...     1572.0        NaN  0.006997
# 4052  Wyoming          56            < 1 year  ...    60874.0      681.7  0.006817
#
# [354 rows x 12 columns]

# %% [markdown]
# i) Use the selected rows above (you can either assign to another variable or keep using dot(.) operator) to chain
# with other functions (groupby, sum, sort_values) to view your data sorted from the highest Crude rate to
# the smallest. This will show the infant mortality rate for all states.

# %%
death.groupby('State').sum().sort_values('Crude Rate', ascending=False)
# Out:
#                       State Code   Deaths   Population  Crude Rate     ratio
# State
# Oklahoma                    3560   656535   65958887.0    200466.0  2.005632
